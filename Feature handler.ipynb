# %%
import pandas as pd

# %%
from load_data import load_data

# %%
df = load_data()

# %%
df
# Out:
#              kingdom                 phylum                  class  \
# sampleID
# 1056013     Bacteria         Proteobacteria    Gammaproteobacteria
# 1056013     Bacteria         Proteobacteria     Betaproteobacteria
# 1056013     Bacteria          Bacteroidetes         Flavobacteriia
# 1056013     Bacteria         Proteobacteria    Gammaproteobacteria
# 1056013     Bacteria         Proteobacteria    Gammaproteobacteria
# 1056013     Bacteria         Proteobacteria                    NaN
# 1056013     Bacteria         Proteobacteria     Betaproteobacteria
# 1056013     Bacteria                    NaN                    NaN
# 1056013     Bacteria         Proteobacteria     Betaproteobacteria
# 1056013     Bacteria         Proteobacteria     Betaproteobacteria
# 1056013     Bacteria         Proteobacteria    Gammaproteobacteria
# 1056013   unassigned                    NaN                    NaN
# 1056013     Bacteria         Proteobacteria    Gammaproteobacteria
# ...

# %%
def all_feature():
#display all possible features
    col = list(df.columns.values)
    for item in col[:6]:
        print (item)
        feature_list = sorted(pd.value_counts(df[item]).index.values)
        print (feature_list)
    for item in col[7:10]:
        print (item)
        feature_list = sorted(pd.value_counts(df[item]).index.values)
        print (feature_list)
    return

# %%
all_feature()
# Out:
# kingdom
# ['Archaea', 'Bacteria', 'Eukaryota', 'unassigned']
# phylum
# ['Acidobacteria', 'Actinobacteria', 'Aquificae', 'Armatimonadetes', 'Bacteroidetes', 'Caldiserica', 'Candidatus Saccharibacteria', 'Chlamydiae', 'Chlorobi', 'Chloroflexi', 'Chrysiogenetes', 'Cloacimonetes', 'Crenarchaeota', 'Cyanobacteria', 'Deferribacteres', 'Deinococcus-Thermus', 'Euryarchaeota', 'Fibrobacteres', 'Firmicutes', 'Fusobacteria', 'Gemmatimonadetes', 'Ignavibacteriae', 'Lentisphaerae', 'Mollusca', 'Nitrospinae', 'Nitrospirae', 'Planctomycetes', 'Poribacteria', 'Proteobacteria', 'Spirochaetes', 'Synergistetes', 'Tenericutes', 'Thaumarchaeota', 'Thermodesulfobacteria', 'Thermotogae', 'Verrucomicrobia']
# class
# ...

# %%
def select_feature(kingdom,phylum,classes,order,family,genus,oxgen,replicate,week):

# %%
d = { i : { j : str(i) + str(j) for j in range(5) } for i in range(5) }

# %%
item = 'kingdom'
item
exec("%s = %d" % (item,[1,1,1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-bbda86ba3b45> in <module>()
#       1 item = 'kingdom'
#       2 item
# ----> 3 exec("%s = %d" % (item,[1,1,1]))
#
# TypeError: %d format: a number is required, not list

# %%
foo = "bar"
exec(foo + " = 'something else'")
print (bar)
# Out:
# something else

# %%
name = 'kingdom' + 'fff'

eval('kingdom' + 'fff') = 1
kindon
# Out:
#   File "<ipython-input-44-9ee8e9a77230>", line 3
#     eval('kingdom' + 'fff') = 1
#                                ^
# SyntaxError: can't assign to function call

# %%
def feature_select(column,featurename):
#features we need

def splitframe(data, name='name'):

    n = data[name][0]

    df = pd.DataFrame(columns=data.columns)

    datalist = []

    for i in range(len(data)):
        if data[name][i] == n:
            df = df.append(data.iloc[i])
        else:
            datalist.append(df)
            df = pd.DataFrame(columns=data.columns)
            n = data[name][i]
            df = df.append(data.iloc[i])

    return datalist

# %%
df.groupby(['kingdom']).get_group('unassigned')
# Out:
#              kingdom phylum class order family  genus   length oxygen  \
# sampleID
# 1056013   unassigned    NaN   NaN   NaN    NaN  other   920784    Low
# 1056016   unassigned    NaN   NaN   NaN    NaN  other   735185    Low
# 1056019   unassigned    NaN   NaN   NaN    NaN  other   802179    Low
# 1056022   unassigned    NaN   NaN   NaN    NaN  other   854736    Low
# 1056025   unassigned    NaN   NaN   NaN    NaN  other  1915802   High
# 1056028   unassigned    NaN   NaN   NaN    NaN  other  1286000   High
# 1056031   unassigned    NaN   NaN   NaN    NaN  other  4261050   High
# 1056034   unassigned    NaN   NaN   NaN    NaN  other   930987   High
# 1056037   unassigned    NaN   NaN   NaN    NaN  other  1092952    Low
# 1056040   unassigned    NaN   NaN   NaN    NaN  other   663582    Low
# 1056043   unassigned    NaN   NaN   NaN    NaN  other   853614    Low
# 1056046   unassigned    NaN   NaN   NaN    NaN  other   693665    Low
# ...

# %%
def feature_remove(featurename):
#Remove features like unassigned or other
# Out:
#   File "<ipython-input-104-e4919d542c8c>", line 2
#     #Remove features like unassigned or other
#                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
def feature_merge(f_name1,f_name2)
#if two features have high coorelation, we may merge these together
# Out:
#   File "<ipython-input-105-1af93f7c4351>", line 1
#     def feature_merge(f_name1,f_name2)
#                                       ^
# SyntaxError: invalid syntax

# %%
files = zf.namelist()
which_file = widgets.Select(options=files)

def select_file(filename):
    return pd.read_csv(zf.open(filename))
    
i = widgets.interactive(select_file, filename=which_file)
display(i)
